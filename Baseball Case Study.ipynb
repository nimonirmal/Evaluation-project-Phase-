# %% [markdown]
# # Name- Nirmal Kumar

# %% [markdown]
# #  <span style="color:brown">****Evaluation Project - 1 : Baseball Case Study****

# %% [markdown]
# ![baseball-player-mid-swing-in-pop-art-hues-photo-photos-big.jpg](attachment:baseball-player-mid-swing-in-pop-art-hues-photo-photos-big.jpg)

# %% [markdown]
# # Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success.
# There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# # Input features
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.

# %% [markdown]
# #  Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics
# For downloading the dataset, use the link given below.

# %% [markdown]
# # Dataset Link-
# •	https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/blob/master/baseball.csv

# %% [markdown]
# # <span style="color:RED">****Documentation****

# %% [markdown]
# <span style="color:green">****Dataset Overview****
#
#  Name  - Baseball Case Study
#  Format- CSV
#  Size  - Rows-30 and Column-17

# %% [markdown]
# <span style="color:green">****Variables****
#
# ['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER','ERA', 'CG', 'SHO', 'SV', 'E']

# %% [markdown]
# <span style="color:green">****Data Cleaning and Preprocessing****
#
# Prior to analysis, the dataset underwent cleaning and preprocessing steps like Handling missing values,
# Checking numbers of unique values in each column, checking Dublicate Values.

# %% [markdown]
# <span style="color:green">****Exploratory Data Analysis (EDA)****
#
# The EDA phase involves the identifying of various trends, patterns, and relationships within the dataset.
# Visualizations and statistical summaries are utilized to derive meaningful insights.
# The EDA results are presented to facilitate a deeper understanding of the sport.

# %% [markdown]
# <span style="color:green">****Training****
#
# Training Data: Rows & Column (20, 13)
# Training Process: Feature Scaling Using Standard Scaler, Multicollinearity, Train on different different model,Finding the Best Random State,

# %% [markdown]
# <span style="color:green">****Evaluation****
#
# Metrics: Use R2 Score, Mean Absolute Error, Mean Squared Error,
#         Root Mean Squared Error used to evaluate the performance of the model.

# %% [markdown]
# <span style="color:green">****Conclusion****
#
# This case study dataset provides for predict the number of predicted wins (W) which is continious data.
# It is clearly a Regression problem where "W" is target column and remaining columns are features.
# Lasso works best in this dataset having R2-score of 0.87 among all model.

# %% [markdown]
# # <span style="color:brown">****Python Implementation****

# %% [markdown]
# <span style="color:green">****Import Necessary Libraries****

# %%
#Data Manipulation
import pandas as pd
import numpy as np
#Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt
#Ignore Unecessary Warning 
import warnings
warnings.filterwarnings("ignore")

# %%
#Importing Dataset
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
print(f'The Number of Rows and Column in Dataset is:{df.shape}')
print(f'The Column name in Dataset are:{df.columns}')
# Out:
# The Number of Rows and Column in Dataset is:(30, 17)
# The Column name in Dataset are:Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# <span style="color:green">****Information of Dataset****

# %%
#Getting all information of Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# <span style="color:blue">****Observation-
# 1)No null values are present in dataset.
# 2)Two data types are present (int64,float64) in dataset.****

# %%
#Checking the ValueCount(i.e frequency of each value) of each Column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %% [markdown]
# <span style="color:blue">****Observation-
# No Blankspace are present in dataset. Lets go ahead.****

# %%
#Checking numbers of unique values in each column
df.nunique().to_frame("No. of Unique Value")
# Out:
#      No. of Unique Value
# W                     24
# R                     28
# AB                    29
# H                     29
# 2B                    22
# 3B                    23
# HR                    27
# BB                    29
# SO                    29
# SB                    27
# RA                    30
# ER                    30
# ERA                   30
# CG                     9
# SHO                   12
# SV                    20
# E                     21

# %%
#Checking Dublicate Values
print("Total Dublicate row are:", df.duplicated().sum())
# Out:
# Total Dublicate row are: 0

# %% [markdown]
# <span style="color:blue">****Observation-
# No Dublicate are present in dataset.****

# %% [markdown]
# <span style="color:green">****Description of Dataset****

# %%
#Satatical summmary of Dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# <span style="color:blue">****Observation -From the above description , we can observe the following things:
#     -No missing values are present in dataset
#     -The mean value is greater than median(50%) in ("AB","H","HR","CG","SV","E"),which means data is skewed right in these.
#     -The mean value is smaller than median(50%) in ("W","2B","BB","SO","RA","ER","ERA","SHO",),which means data is skewed left in these.
#     -There is difference in 75% and max value in few columns ,it means Outliers are present in the dataset.****

# %% [markdown]
# # <span style="color:brown">****Data Visualization****

# %%
#Create a method to check for Data distribution,Relationship and Boxplot in each feature columns
def graph_plot(df,i):
    plt.figure(figsize = (15,5))
    plt.subplot(1,3,1)
    sns.histplot(x=i,data=df,kde=True,color='g')
    plt.subplot(1,3,2)
    sns.regplot(x=i,y='W',data=df,)
    plt.subplot(1,3,3)
    sns.boxplot(y=i,data=df)
    plt.show()

# %%
# R= Runs scored.
graph_plot(df,"R")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data Distribution is Normal.
# Runs is linearly correlated with Win.
# Only One Outlier is present in between 850-900.****

# %%
#AB - This means At bat or time at bat.
graph_plot(df,"AB")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data Distribution is little right skewed.
# Most Data points are ditributed randomly, Hence no significant relation with Win.
# No Outlier is present.****

# %%
# H - This means Hit. It's also called a "base hit"
graph_plot(df,"H")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data Distribution is right skewed.
# Most Data points are ditributed randomly, Hence no significant relation with Win.
# No Outlier is present.****

# %%
# 2B- Dubles
graph_plot(df,"2B")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data Distribution is left skewed.
# "2B" is linearly related with Win..
# No Outlier is present.****

# %%
# 3B - This measns a Triple.
graph_plot(df,"3B")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data Distribution is Normal.
# "3B" is weak negative correlated with Win..
# No Outlier is present.****

# %%
# HR - This means Home runs. 
graph_plot(df,"HR")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data Distribution is little right skewed.
# "HR" is very low correlation with Win..
# No Outlier is present.****

# %%
# BB - This means Base on balls (also called a "walk").
graph_plot(df,"BB")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data Distribution is little left skewed.
# "BB" is very lightly correlated with Win..
# No Outlier is present.****

# %%
# SO - Also denoted as "K" means Strikeout. 
graph_plot(df,"SO")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data Distribution is left skewed.
# "SO" has no relation with Win..
# No Outlier is present.****

# %%
# SB - This means Stolen base
graph_plot(df,"SB")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data is normally distributed.
# "SB" is not correlated to Win.
# No Outlier is present.****

# %%
#RA - This means Run Average. 
graph_plot(df,"RA")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data is left skew distributed.
# "RA" is highly negative correlated to Win.
# No Outlier is present.****

# %%
#ER - This means Earned run.
graph_plot(df,"ER")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data is left skew distributed.
# "ER" is highly negative correlated to Win.
# No Outlier is present.****

# %%
# ERA - This means Earned Run Average. 
graph_plot(df,"ERA")

# %% [markdown]
# <span style="color:blue">****Observation-
# Left skew data distribution.
# "ERA" is highly negative correlated to Win.
# Only One Outlier is present.****

# %%
#CG - This means Complete Game.
graph_plot(df,"CG")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data is right skewed distributed.
# "CG" is not correlated to Win.
# No Outlier is present.****

# %%
#SHO - This means Shutout.
graph_plot(df,"SHO")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data is little left skewed distributed.
# "CG" is lightly correlated to Win.
# One Outlier is present.****

# %%
# SV - This means Save.
graph_plot(df,"SV")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data is right skewed distributed.
# "SV" is moderately correlated to Win.
# One Outlier is present.****

# %%
# E - This means Errors.
graph_plot(df,"E")

# %% [markdown]
# <span style="color:blue">****Observation-
# Data is right skewed distributed.
# "E" is not correlated to Win.
#  Outliers are present.****

# %%
# Multivariate Analysis
plt.figure(figsize = (40,20))
sns.pairplot(df)
plt.show()

# %% [markdown]
# <span style="color:blue">****Observation- From the above plot we can observ that column "RA","ER","ERA" are highly correlated with each other which can cause multicollinearity.****

# %% [markdown]
# # <span style="color:brown">****Removing Outliers****

# %% [markdown]
# <span style="color:black">****Some features has Outliers.Lets remove Outliers by IQR method or Z-score method.****

# %% [markdown]
# <span style="color:green">****Removing Outliers by zscore****

# %%
from scipy.stats import zscore
outliers_feature = df[["R","ERA", 'SHO', 'SV', 'E']]
z=np.abs(zscore(outliers_feature)) #.abs() to remove negative values

# %% [markdown]
# <span style="color:GREEN">In normal distribution, it is estimated that
# 68% of the data points lie between +/- 1 standard deviation.
# 95% of the data points lie between +/- 2 standard deviation
# 99.7% of the data points lie between +/- 3 standard deviation

# %%
#Z-score>3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
#checkling the value of z-score
print(z.iloc[5,0])
# Out:
# 3.5096470447193067

# %% [markdown]
# <span style="color:BLUE">****Observation -Here the value is greater than 3.Let's remove it****

# %%
#now removing the data above zscore and creating a new dataframe
df1=df[(z<3).all(axis=1)]
print("New Dataframe having rows and column: " ,df1.shape)
print("New Dataframe column's name: " ,df1.columns)
# Out:
# New Dataframe having rows and column:  (29, 17)
# New Dataframe column's name:  Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
print("Data Loss Percentage with Z-score method:",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage with Z-score method: 3.3333333333333335

# %% [markdown]
# <span style="color:green">****Removing Outliers by IQR (Inter Quantile Method)****

# %%
#1st Quantile
q1=outliers_feature.quantile(0.25)

#3rd Quantile
q3=outliers_feature.quantile(0.75)

#calculating IQR
iqr=q3-q1

df2=df[~((df < (q1 - 1.5*iqr ))|(df > (q3 + 1.5*iqr ))).any(axis=1)]

# %%
print("Data Loss Percentage with Z-score method:",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage with Z-score method: 33.33333333333333

# %% [markdown]
# <span style="color:blue">****Conclusion -Data Loss Percentage  with IQR method is very high as compared with Z-score . So i go with z-score****

# %%
#Storing Dataframe with Z-score method in old dataframe
df=df1

# %%
#reset the index after removing outliers values
df.reset_index( drop=True, inplace=True)

# %% [markdown]
# # <span style="color:brown">****Removing Skewness****

# %%
# Checking Skewness
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
#Removing Skewness using cuberoot,square-root,Log method
df['H']=np.cbrt(df['H'])
df['CG']=np.sqrt(df['CG'])
df['SV']=np.cbrt(df['SV'])
df['E']=np.log(df['E'])

print("H :",df["H"].skew())
print("CG :",df["CG"].skew())
print("SV :",df["SV"].skew())
print("E :",df["E"].skew())
# Out:
# H : 0.7536959466136843
# CG : -0.2606778075812151
# SV : 0.2809633925573293
# E : 0.5833075389348484

# %%
#Removing Skewness using cuberoot again in "H" column  
df['H']=np.cbrt(df['H'])
print("H :",df["H"].skew())
# Out:
# H : 0.743531163938305

# %% [markdown]
# <span style="color:BLUE">****Observation -Hence we removed skewness at some limit, after this if we remove skewness then we get NaN value.
# Let's go with this value.****

# %% [markdown]
# # <span style="color:brown">****Checking Correlation****

# %%
#checking Correlation statically
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.020513  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.432387  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.770055  0.490752  0.445604 -0.064653
# H   -0.020513  0.432387  0.770055  1.000000  0.527433  0.579998 -0.219151
# 2B   0.384886  0.469293  0.490752  0.527433  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.579998  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.219151 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.221834  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.373148 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.419950  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.243748 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.280025 -0.224993  0.333731 -0.062094
# ...

# %%
#checking the corelation  again using heatmaps (only absolute values)
plt.figure(figsize = (15,7))
sns.heatmap(df.corr(), annot = True, linewidths=0.5, fmt='.2f',cmap = "YlGnBu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <span style="color:blue">****Obsevation- We can see that column ("RA","ER","ERA") are highly correlated with each other and ("AB","H") are strongly correlated with each other which can cause multicollinearity we will check again and remove it later.****

# %% [markdown]
# # <span style="color:brown">****Seperating Feature and Label****

# %%
#Seperating Feature and label into x and y
x=df.drop(["W"],axis=1)
y=df["W"]
print("Feature Dimension :" ,x.shape)
print("Target Dimension :" ,y.shape)
# Out:
# Feature Dimension : (29, 16)
# Target Dimension : (29,)

# %% [markdown]
# # <span style="color:brown">****Feature Scaling Using Standard Scaler****

# %%
# data scaling 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %% [markdown]
# # <span style="color:brown">****Detecting Multicollinearity Using a Variance Inflation Factor (VIF)****

# %%
#finding VIF in each scaled column i.e x_scaled.shape[1](1/1- R^2 )
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame() 

vif["VIF"] = [variance_inflation_factor(x_scaled.values, i) for i in range(len(x_scaled.columns))]
vif["Features"] = x_scaled.columns
vif
# Out:
#             VIF Features
# 0      7.076763        R
# 1     18.108984       AB
# 2      9.287927        H
# 3      3.833031       2B
# 4      3.298708       3B
# 5      8.604739       HR
# 6      3.545940       BB
# 7      2.857748       SO
# 8      1.994116       SB
# 9    201.082836       RA
# 10  1903.958285       ER
# 11  1481.812231      ERA
# 12     2.891385       CG
# 13     3.597262      SHO
# 14     5.242425       SV
# 15     2.162983        E

# %% [markdown]
# <span style="color:blue">****Observation - THe VIF value is high in "ER",We will drop "ER" which shows high collinearity.
# Lets Check again ViF value of other feature are reduced or not.****

# %%
#Dropping "ER"  Column
x_scaled.drop(["ER"],axis=1, inplace =True)

# %%
#checking Multicollinearity again 
vif=pd.DataFrame() 

vif["VIF"] = [variance_inflation_factor(x_scaled.values, i) for i in range(len(x_scaled.columns))]
vif["Features"] = x_scaled.columns
vif
# Out:
#            VIF Features
# 0     6.224912        R
# 1     7.508218       AB
# 2     8.815096        H
# 3     3.521629       2B
# 4     3.255400       3B
# 5     7.505948       HR
# 6     3.545924       BB
# 7     2.847127       SO
# 8     1.842135       SB
# 9   146.333569       RA
# 10  143.084362      ERA
# 11    2.568680       CG
# 12    3.479264      SHO
# 13    2.533843       SV
# 14    2.105901        E

# %%
#Dropping "RA"  Column
x_scaled.drop(["RA"],axis=1, inplace =True)

# %%
#checking Multicollinearity again 
vif=pd.DataFrame() 

vif["VIF"] = [variance_inflation_factor(x_scaled.values, i) for i in range(len(x_scaled.columns))]
vif["Features"] = x_scaled.columns
vif
# Out:
#          VIF Features
# 0   6.217559        R
# 1   4.749717       AB
# 2   7.557475        H
# 3   3.511342       2B
# 4   3.217187       3B
# 5   6.349597       HR
# 6   3.187799       BB
# 7   2.252330       SO
# 8   1.786654       SB
# 9   4.999226      ERA
# 10  2.566707       CG
# 11  3.243891      SHO
# 12  2.441706       SV
# 13  2.057015        E

# %% [markdown]
# <span style="color:blue">****Observation - THe VIF value is below 10 in all feature ,Hence multicollinearity problem is solved now.
# Lets go ahead.****

# %% [markdown]
# # <span style="color:brown">****Feature Selection by using SelectKBest Method****

# %%
from sklearn.feature_selection import SelectKBest,f_classif
best_fit = SelectKBest(score_func=f_classif, k=14)
fit = best_fit.fit_transform(x_scaled,y)

#Create Dataframe to display Feature and Score 
df_scores= pd.DataFrame({"Feature" :x_scaled.columns, "Score" : best_fit.scores_ })

df_scores = df_scores.sort_values(by='Score', ascending=False)
top_features = df_scores.head(14)
print(top_features)
# Out:
#    Feature     Score
# 8       SB  3.283197
# 13       E  2.997219
# 0        R  2.485509
# 12      SV  2.190896
# 9      ERA  1.732208
# 1       AB  1.622586
# 7       SO  1.519889
# 11     SHO  1.253358
# 6       BB  0.943327
# 5       HR  0.818974
# 4       3B  0.811129
# 3       2B  0.799063
# 2        H  0.729117
# 10      CG  0.427401

# %% [markdown]
# <span style="color:blue">****Observation -The "CG" has very low score for model prediction. Lets drop the "CG" column.****

# %%
#Dropping "CG"  Column
x_scaled.drop(["CG"],axis=1, inplace =True)

# %%
x_scaled.shape
# Out:
# (29, 13)

# %% [markdown]
# # <span style="color:brown">****Modelling****

# %% [markdown]
# <span style="color:green">****Finding the Best Random State****

# %%
#Importing Necessary Libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

#finding the best random state
maxAccu=0
maxRS=0
for i in range(1,200):
    # Split the data into training and testing sets
    x_train,x_test,y_train,y_test = train_test_split (x_scaled, y, test_size = .30, random_state = i)
    
    # Loading linear regression model
    lr = LinearRegression()
    # Fit the model on the training data
    lr.fit(x_train, y_train)
    # Predict the target variable for the test data
    y_pred = lr.predict(x_test)
    acc = r2_score(y_test, y_pred)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 Score is ",maxAccu,"on Random State ",maxRS)
# Out:
# Maximum R2 Score is  0.9340031253271378 on Random State  50

# %% [markdown]
# # <span style="color:brown">****Split the data into training and testing sets****

# %%
# Split the data into training and testing sets 
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split (x_scaled, y, test_size = .30, random_state = maxRS)
print("Total Size Of Feature in Dataset :",x_scaled.shape)
print("Total Size Of Training Feature Dataset : " ,x_train.shape)
print("Total Size Of Testing Feature Dataset : ", x_test.shape)

print("Total Size Of Label in Dataset :",y.shape)
print("Total Size Of Training Label Dataset : " ,y_train.shape)
print("Total Size Of Testing Label Dataset : ", y_test.shape)
# Out:
# Total Size Of Feature in Dataset : (29, 13)
# Total Size Of Training Feature Dataset :  (20, 13)
# Total Size Of Testing Feature Dataset :  (9, 13)
# Total Size Of Label in Dataset : (29,)
# Total Size Of Training Label Dataset :  (20,)
# Total Size Of Testing Label Dataset :  (9,)

# %% [markdown]
# # <span style="color:brown">****Create one function and call as many as times to check score of different model****

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

def model_score(model_name,x_train,x_test,y_train,y_test, train=True):
    if train: #checking training score 
        y_pred_train=model_name.predict(x_train)
        
        print("\n*********************Train Result*********************")
        
        print("R2 Score on train data:",r2_score(y_train,y_pred_train))
        
    elif train==False: #checking testing score 
        y_pred_test=model_name.predict(x_test)
        
        print("\n*********************Test Result*********************")
        
        print("R2 Score on test data:",r2_score(y_test,y_pred_test))
        print("Mean Absolute Error :",mean_absolute_error(y_test,y_pred_test))
        print("Mean Squared Error :",mean_squared_error(y_test,y_pred_test))
        print("Root Mean Squared Error :",np.sqrt(mean_squared_error(y_test,y_pred_test)))

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train, y_train)

#Call the function and pass datset to check train and test score 
model_score(LR,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(LR,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.9015829747750607
#
# *********************Test Result*********************
# R2 Score on test data: 0.9340031253271378
# Mean Absolute Error : 2.419510628338953
# Mean Squared Error : 9.470958903670985
# Root Mean Squared Error : 3.0774923076542344

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(x_train, y_train)
#Call the function and pass datset to check train and test score 
model_score(ridge,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(ridge,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.8970435621764865
#
# *********************Test Result*********************
# R2 Score on test data: 0.9369508087259767
# Mean Absolute Error : 2.442140176326853
# Mean Squared Error : 9.047948140361074
# Root Mean Squared Error : 3.0079807413547504

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(x_train, y_train)
#Call the function and pass datset to check train and test score 
model_score(lasso,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(lasso,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.8595135512975713
#
# *********************Test Result*********************
# R2 Score on test data: 0.8658977904513138
# Mean Absolute Error : 3.780329422526432
# Mean Squared Error : 19.244494861653447
# Root Mean Squared Error : 4.3868547800962645

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
Decision_tree = DecisionTreeRegressor()
Decision_tree.fit(x_train, y_train)
#Call the function and pass datset to check train and test score 
model_score(Decision_tree,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(Decision_tree,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 1.0
#
# *********************Test Result*********************
# R2 Score on test data: 0.2969717825189263
# Mean Absolute Error : 9.333333333333334
# Mean Squared Error : 100.88888888888889
# Root Mean Squared Error : 10.044346115546242

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest=RandomForestRegressor()
random_forest.fit(x_train, y_train)
#Call the function and pass datset to check train and test score 
model_score(random_forest,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(random_forest,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.9198500173792146
#
# *********************Test Result*********************
# R2 Score on test data: 0.6715891947694426
# Mean Absolute Error : 5.864444444444443
# Mean Squared Error : 47.12897777777776
# Root Mean Squared Error : 6.865054827004498

# %% [markdown]
# # AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
adaboost = AdaBoostRegressor()
adaboost.fit(x_train,y_train)
#Call the function and pass datset to check train and test score 
model_score(adaboost,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(adaboost,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.9922023550083533
#
# *********************Test Result*********************
# R2 Score on test data: 0.6753948726772194
# Mean Absolute Error : 6.337037037037039
# Mean Squared Error : 46.58283950617286
# Root Mean Squared Error : 6.825162232956288

# %% [markdown]
# # Support Vector Regression (SVR)

# %%
from sklearn.svm import SVR
svm=SVR()
svm.fit(x_train,y_train)
#Call the function and pass datset to check train and test score 
model_score(svm,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(svm,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.18974378985705176
#
# *********************Test Result*********************
# R2 Score on test data: 0.11429064204650707
# Mean Absolute Error : 10.214509574134858
# Mean Squared Error : 127.10476020804198
# Root Mean Squared Error : 11.274074694095386

# %% [markdown]
# # <span style="color:green">Here we see that LinearRegression, Ridge, Lasso works the best in this dataset with accuracy 93.4%, 93.6%, 86.5% respectively. Let,s check wheather these model are Overfitted or not.

# %% [markdown]
# # <span style="color:Brown">****Cross-Validation score- to check if the model is overfitting****

# %%
from sklearn.model_selection import cross_val_score

# %%
#Linear Regression
print("Cross-Validation score of each fold of Dataset:",cross_val_score(LR,x_scaled,y,cv=5))
print("Overall Cross-Validation score :",cross_val_score(LR,x_scaled,y,cv=5).mean())
# Out:
# Cross-Validation score of each fold of Dataset: [ 0.2593126  -1.10836859  0.57829244  0.70267473  0.80756673]
# Overall Cross-Validation score : 0.2478955796341033

# %%
#Ridge Regression
print("Cross-Validation score of each fold of Dataset:",cross_val_score(ridge,x_scaled,y,cv=5))
print("Overall Cross-Validation score :",cross_val_score(ridge,x_scaled,y,cv=5).mean())
# Out:
# Cross-Validation score of each fold of Dataset: [ 0.49644392 -1.15597759  0.65401651  0.85301931  0.85882513]
# Overall Cross-Validation score : 0.3412654565617389

# %%
#Lasso Regression
print("Cross-Validation score of each fold of Dataset:",cross_val_score(lasso,x_scaled,y,cv=5))
print("Overall Cross-Validation score :",cross_val_score(lasso,x_scaled,y,cv=5).mean())
# Out:
# Cross-Validation score of each fold of Dataset: [ 0.74387319 -0.80021855  0.7815277   0.78780627  0.8794163 ]
# Overall Cross-Validation score : 0.4784809834697086

# %% [markdown]
# # <span style="color:green">Conclusion-Out of three model, Lasso Regression has less Overfitted. Lets go with Lasso model to increase accuracy by HyperParameter Tuning.

# %% [markdown]
# # HyperParameter Tuning for Lasso Model

# %%
from sklearn.model_selection import  GridSearchCV

# %%
lasso.get_params().keys()
# Out:
# dict_keys(['alpha', 'copy_X', 'fit_intercept', 'max_iter', 'normalize', 'positive', 'precompute', 'random_state', 'selection', 'tol', 'warm_start'])

# %%
parameters= {'alpha': [0.1, 0.5, 1.0],  
    'fit_intercept': [True, False],
    'precompute': [False],  
    'copy_X': [True, False],
    'max_iter': [500, 1000, 1500],  
    'tol': [1e-3, 1e-4, 1e-5]  }

# %%
Grid_cv=GridSearchCV(Lasso(),parameters,cv=5)

# %%
Grid_cv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.1, 0.5, 1.0], 'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'max_iter': [500, 1000, 1500], 'precompute': [False],
#                          'tol': [0.001, 0.0001, 1e-05]})

# %%
Grid_cv.best_params_
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 500,
#  'precompute': False,
#  'tol': 0.001}

# %%
lasso_grid=Lasso(alpha= 1.0,
           copy_X= True,
        fit_intercept =True,
        max_iter= 500,
       precompute = False,
          tol= 0.001)
lasso_grid.fit(x_train, y_train)
#Call the function and pass datset to check train and test score 
model_score(lasso_grid,x_train,x_test,y_train,y_test, train=True) #This is training score
model_score(lasso_grid,x_train,x_test,y_train,y_test, train=False) #This is testing score
# Out:
# *********************Train Result*********************
# R2 Score on train data: 0.8595089027977975
#
# *********************Test Result*********************
# R2 Score on test data: 0.8659034126386171
# Mean Absolute Error : 3.7798723646126495
# Mean Squared Error : 19.243688043070545
# Root Mean Squared Error : 4.38676282047144

# %% [markdown]
# #  <span style="color:green">Clearly Lasso Model best for this dataset out of all models after hyperparameter tunnning and has best R2-score of 0.87.

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(lasso_grid,'Model to Predict Number of Wins (W)')
# Out:
# ['Model to Predict Number of Wins (W)']

# %% [markdown]
# # Model Prediction

# %%
lasso_grid_model = joblib.load('Model to Predict Number of Wins (W)')
win = lasso_grid_model.predict(x_test)
win
# Out:
# array([69.14464732, 79.57348124, 76.71063539, 82.356627  , 74.48746157,
#        71.07089175, 87.15470636, 89.19997233, 96.2569603 ])

# %% [markdown]
# # Comparing Model Prediction with Orignal Value

# %%
test_data = np.array(y_test)
win_prediction= pd.DataFrame({'predicted': win,'original':test_data})
win_prediction
# Out:
#    predicted  original
# 0  69.144647        68
# 1  79.573481        78
# 2  76.710635        74
# 3  82.356627        88
# 4  74.487462        68
# 5  71.070892        64
# 6  87.154706        92
# 7  89.199972        90
# 8  96.256960       100

# %% [markdown]
# # Hence Our Model's Predicted value nearer to Orignal value.
